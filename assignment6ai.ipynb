# %% [markdown]
# <a href="https://colab.research.google.com/github/mansii2022/AIMCASEM2-202301034-/blob/main/assignment6ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import copy
import heapq

q = []
visited = []

def find_pos(s):
  for i in range(len(s)):
    for j in range(len(s[0])):
      if s[i][j] == 0:
        return([i,j])

def up(s,pos):
  i = pos[0]
  j = pos[1]
  if i > 0:
    temp = copy.deepcopy(s)
    temp[i][j] = temp[i-1][j]
    temp[i-1][j] = 0
    return (temp)
  else:
    return (s)

def down(s,pos):
  i = pos[0]
  j = pos[1]
  if i < 2:
    temp = copy.deepcopy(s)
    temp[i][j] = temp[i+1][j]
    temp[i+1][j] = 0
    return (temp)
  else:
    return (s)

def right(s,pos):
  i = pos[0]
  j = pos[1]
  if j < 2:
    temp = copy.deepcopy(s)
    temp[i][j] = temp[i][j+1]
    temp[i][j+1] = 0
    return (temp)
  else:
    return (s)

def left(s,pos):
  i = pos[0]
  j = pos[1]
  if j > 0:
    temp = copy.deepcopy(s)
    temp[i][j] = temp[i][j-1]
    temp[i][j-1] = 0
    return (temp)
  else:
    return (s)

def manhattan_distance(s, g):
  distance = 0
  for i in range(3):
    for j in range(3):
      if s[i][j] != 0:
        goal_i = (s[i][j] - 1) // 3
        goal_j = (s[i][j] - 1) % 3
        distance += abs(i - goal_i) + abs(j - goal_j)
  return distance

def enqueue(s, g, cost):
  global q
  heapq.heappush(q, (cost + manhattan_distance(s, g), s))

def dequeue():
  global q
  s = heapq.heappop(q)
  return s

def search(s, g):
  curr_state = copy.deepcopy(s)
  if s == g:
    return
  c = 0
  print('checking state ', c, curr_state)
  visited.append(s)
  enqueue(curr_state, g, 0)
  while(q):
    curr_state = dequeue()
    c += 1
    if curr_state in visited:
      continue
    visited.append(curr_state)
    if curr_state == g:
      print("found")
      return
    pos = find_pos(curr_state)
    new = up(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new, g, c)
    new = down(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new, g, c)
    new = right(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new, g, c)
    new = left(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new, g, c)
  print("not found")

def main():
  s = [[2,0,3],[1,8,4],[7,6,5]]
  g = [[1,2,3],[8,0,4],[7,6,5]]

  search(s, g)

if __name__ == "__main__":
  main()
# Out:
# checking state  0 [[2, 0, 3], [1, 8, 4], [7, 6, 5]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-42593f2e64e3> in <cell line: 115>()
#     114
#     115 if __name__ == "__main__":
# --> 116   main()
#
# <ipython-input-3-42593f2e64e3> in main()
#     111   g = [[1,2,3],[8,0,4],[7,6,5]]
#     112
# --> 113   search(s, g)
#     114
#     115 if __name__ == "__main__":
#
# <ipython-input-3-42593f2e64e3> in search(s, g)
#      92       print("found")
#      93       return
# ---> 94     pos = find_pos(curr_state)
#      95     new = up(curr_state, pos)
#      96     if new != curr_state and new not in visited:
#
# <ipython-input-3-42593f2e64e3> in find_pos(s)
#       8 def find_pos(s):
#       9   for i in range(len(s)):
# ---> 10     for j in range(len(s[0])):
#      11       if s[i][j] == 0:
#      12         return([i,j])
#
# ...

# %%
import sys
import copy

q = []
visited = []

def find_pos(s):
  for i in range(len(s)):
    for j in range(len(s[0])):
      if s[i][j] == 0:
        return([i,j])

def up(s,pos):
  i = pos[0]
  j = pos[1]
  if i > 0:
    temp = copy.deepcopy(s)
    temp[i][j] = temp[i-1][j]
    temp[i-1][j] = 0
    return (temp)
  else:
    return (s)

def down(s,pos):
  i = pos[0]
  j = pos[1]
  if i < 2:
    temp = copy.deepcopy(s)
    temp[i][j] = temp[i+1][j]
    temp[i+1][j] = 0
    return (temp)
  else:
    return (s)

def right(s,pos):
  i = pos[0]
  j = pos[1]
  if j < 2:
    temp = copy.deepcopy(s)
    temp[i][j] = temp[i][j+1]
    temp[i][j+1] = 0
    return (temp)
  else:
    return (s)

def left(s,pos):
  i = pos[0]
  j = pos[1]
  if j > 0:
    temp = copy.deepcopy(s)
    temp[i][j] = temp[i][j-1]
    temp[i][j-1] = 0
    return (temp)
  else:
    return (s)

def manhattan_distance(s, g):
  distance = 0
  for i in range(3):
    for j in range(3):
      if s[i][j] != 0:
        goal_i = (s[i][j] - 1) // 3
        goal_j = (s[i][j] - 1) % 3
        distance += abs(i - goal_i) + abs(j - goal_j)
  return distance

def enqueue(s):
  global q
  q.append(s)

def dequeue():
  global q
  s = q.pop(0)
  return s

def search(s, g):
  curr_state = copy.deepcopy(s)
  if s == g:
    return
  c = 0
  print('checking state ', c, curr_state)
  visited.append(s)
  enqueue(curr_state)
  while(q):
    curr_state = dequeue()
    c += 1
    if curr_state in visited:
      continue
    visited.append(curr_state)
    if curr_state == g:
      print("found")
      return
    pos = find_pos(curr_state)
    new = up(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new)
    new = down(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new)
    new = right(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new)
    new = left(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new)
  print("not found")

def main():
  s = [[2,0,3],[1,8,4],[7,6,5]]
  g = [[1,2,3],[8,0,4],[7,6,5]]

  enqueue(s)
  while(q):
    curr_state = dequeue()
    visited.append(curr_state)
    if curr_state == g:
      print("found")
      return
    pos = find_pos(curr_state)
    new = up(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new)
    new = down(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new)
    new = right(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new)
    new = left(curr_state, pos)
    if new != curr_state and new not in visited:
      enqueue(new)
    search(s, g)
if __name__ == "__main__":
  main()
# Out:
# checking state  0 [[2, 0, 3], [1, 8, 4], [7, 6, 5]]
# found
# checking state  0 [[2, 0, 3], [1, 8, 4], [7, 6, 5]]
